# %% [markdown]
# # **LangSplat : 3D Language Gaussian Splatting**
#
#
# This paper comes with efficient and practical method which constructs a 3D Language fields that enables the precise and efficient open-vocabulary querying within 3D spaces.
#
# This helps user to model and query 3D spaces using natural language vocabularies.
#
# **Note**: This paper was released with a collaboration between Chinese researchers and Harvard University.

# %% [markdown]
# _____
# Limitations posed by Previous Methods:
# 1. Previous methods like **LERF** which is based on NeRFs. This method suffers in both speed and accuracy, thus constraining practical applicability.
# It is also computationally expensive in terms of rendering.

# %%
# New mthods used to overcome the limitations posed by older methods:

# %% [markdown]
# """
# 1. Replacing Neural Radiance method with **Gauss Splatting** for 3D representations.
# 2. Replacing DINO model with **SAM model** to capture hierarchical regions. CLIP embeddings are aligned with images rather than pixels. This circumvents the need for intensive searches across multiple absolute scales and the auxiliary DINO features, thereby effectively improving **efficiency**.
# 3. It learn language features on the scene-specific latent space to reduce the
# memory cost. Language Fields are set to each gaussian splats.
#
#
# ![image.png](data:image/png;base64,...)
#
# """
